# %%
print("Welcome to Jupyter!")
print("This is fun!")
# Out:
# Welcome to Jupyter!
# This is fun!

# %%
x=8

# %%
print(x)
# Out:
# 8

# %%
from pathlib import Path

# %%
base_dir= Path.cwd()
csv_path = base_dir/"student_grades.csv"

# %%
#Import Pandas into our program and give it an alias of pd
import pandas as pd

# %%
#load the contents from the csv file into a dataframe
#A dataframe is a 2 dimensional view of the data
grades = pd.read_csv(csv_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 #load the contents from the csv file into a dataframe
#       2 #A dataframe is a 2 dimensional view of the data
# ----> 3 grades = pd.read_csv(csv_path)
#
# File C:\W\April 7\A05\Pandas_Jupyter\myvenv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#display a dataframe
grades
# Out:
#       Name    Class  Grade
# 0    Alice     Math     88
# 1      Bob     Math     92
# 2  Charlie  Science     85
# 3     Dana     Math     76
# 4      Eli  Science     90

# %%
grades.head()#shows the first 5 rows
# Out:
#       Name    Class  Grade
# 0    Alice     Math     88
# 1      Bob     Math     92
# 2  Charlie  Science     85
# 3     Dana     Math     76
# 4      Eli  Science     90

# %%
grades.info()#summary info of the dataframe
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Class   5 non-null      str
#  2   Grade   5 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 252.0 bytes

# %%
grades.shape# how many rows and columns
# Out:
# (5, 3)

# %%
grades.describe()#returns some statistics
# Out:
#           Grade
# count   5.00000
# mean   86.20000
# std     6.26099
# min    76.00000
# 25%    85.00000
# 50%    88.00000
# 75%    90.00000
# max    92.00000

# %%
#Create a dataframe of only the math students
math_students = grades[grades["Class"] == "Math"]
math_students
# Out:
#     Name Class  Grade
# 0  Alice  Math     88
# 1    Bob  Math     92
# 3   Dana  Math     76

# %%
#How many math students are there?
math_students.shape[0]
# Out:
# 3

# %%
#sort the math records from highest grade to lowest and display
top_math  = math_students.sort_values(by = "Grade", ascending = False)
top_math
# Out:
#     Name Class  Grade
# 1    Bob  Math     92
# 0  Alice  Math     88
# 3   Dana  Math     76

# %%
#Top math student record
#the first record in the dataframe
top_math.iloc[0]
# Out:
# Name      Bob
# Class    Math
# Grade      92
# Name: 1, dtype: object

# %%
#Exercise!
#Get the science records and display them
science_students = grades[grades["Class"] == "Science"]
science_students
# Out:
#       Name    Class  Grade
# 2  Charlie  Science     85
# 4      Eli  Science     90

# %%
#sort the science records from hightest to lowest grade
top_science  = science_students.sort_values(by = "Grade", ascending = False)
top_science
# Out:
#       Name    Class  Grade
# 4      Eli  Science     90
# 2  Charlie  Science     85

# %%
#Display the the highest grade science record
top_science.iloc[0]
# Out:
# Name         Eli
# Class    Science
# Grade         90
# Name: 4, dtype: object

# %%
#OR
science_students.sort_values(by = "Grade", ascending = False).iloc[0]
# Out:
# Name         Eli
# Class    Science
# Grade         90
# Name: 4, dtype: object
